# %%
from sklearn.datasets import load_iris
import pandas as pd
import numpy as np

# %%
data=load_iris()

# %%
X=data.data

# %%
data.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
X=pd.DataFrame(X,columns=data.feature_names)

# %%
X
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
temp=sorted(X['sepal length (cm)'].tolist())

# %%
quantiles=[]
for i in range(1,101):
    quantiles.append(np.percentile(temp,i))

# %%
theoretical_data=np.random.normal(loc=0,scale=1,size=100)

# %%
theo_quant=[]
for i in range(1,101):
    theo_quant.append(np.percentile(theoretical_data,i))

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(quantiles,theo_quant)

# %%
import statsmodels.api as sm

# %%
fig=sm.qqplot(X['sepal length (cm)'],line='45',fit=True)
plt.title('qq plot')
# Out:
# Text(0.5, 1.0, 'qq plot')

# %%
uniform_data=np.random.uniform(low=0,high=1,size=1000)

# %%
plt.hist(uniform_data)
# Out:
# (array([ 88., 115., 106.,  84.,  92., 102., 107., 104.,  89., 113.]),
#  array([9.69945846e-04, 1.00765540e-01, 2.00561133e-01, 3.00356727e-01,
#         4.00152321e-01, 4.99947915e-01, 5.99743509e-01, 6.99539102e-01,
#         7.99334696e-01, 8.99130290e-01, 9.98925884e-01]),
#  <BarContainer object of 10 artists>)

# %%
import scipy.stats as stats

# %%
params=stats.uniform.fit(uniform_data)
dist=stats.uniform(loc=params[0],scale=params[1])

# %%
fig=sm.qqplot(uniform_data,dist=dist,line='45')
plt.title('qq plot of uniform data with uniform fit')
plt.show()
